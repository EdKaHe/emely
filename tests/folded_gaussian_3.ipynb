# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy.optimize import curve_fit as scipy_curve_fit
from scipy.stats import foldnorm
import time

from emely import curve_fit as emely_curve_fit

# %%
# define plot style
violet = "#785ef0"
blue = "#648fff"
yellow = "#ffb000"
orange = "#fe6100"
red = "#dc267f"
black = "000000"
gray = "cccccc"
white = "ffffff"

plt.style.use("seaborn-v0_8")
plt.rcParams["figure.dpi"] = 300

# %% [markdown]
# ### Overview
#
# This notebook performs tests to validate the parameter estimates and covariance matrices obtained when fitting a Gaussian model with **folded Gaussian noise** of unknown absolute variance.
#
# The estimated parameters and covariances from the MLE implementation are compared against:
#
# - The parameter estimates and covariances from scipy.optimize.curve_fit.
# - The empirical covariance matrices obtained by repeatedly fitting noisy datasets generated from the same Gaussian model.
#
# ### Model and noise
#
# We estimate the parameters $\theta = (a, \mu, \sigma)$ of a normalized Gaussian function:
#
# $
# f(x, \theta) = \frac{a}{\sqrt{2\pi\,\sigma^2}} \, e^{-\frac{(x - \mu)^2}{2\sigma^2}}
# $,
#
# from noisy measurements
#
# $
# y(x) = f(x, \theta) + \varepsilon
# $,
#
# where the noise term $ \varepsilon $ follows **folded Gaussian statistics**.
#
# ### Physical Context
#
# This setup reflects a intensity measurement where the amplitude $a$ is given by the incident power $P$
#
# $
# a = P
# $.

# %%
# define the model to fit
def gaussian(x, a, mu, sigma):
    return a / np.sqrt(2 * np.pi * sigma**2) * np.exp(-((x - mu) ** 2) / (2 * sigma**2))

# %%
# define estimators
estimators = {
    "Least-Squares": lambda f,
    xdata,
    ydata,
    p0,
    bounds,
    sigma,
    absolute_sigma: scipy_curve_fit(
        f,
        xdata,
        ydata,
        p0=p0,
        bounds=bounds,
        sigma=sigma,
        absolute_sigma=absolute_sigma,
    ),
    "Gaussian-MLE": lambda f,
    xdata,
    ydata,
    p0,
    bounds,
    sigma,
    absolute_sigma: emely_curve_fit(
        f,
        xdata,
        ydata,
        p0=p0,
        bounds=bounds,
        sigma=sigma,
        absolute_sigma=absolute_sigma,
        noise="gaussian",
    ),
    "Folded-Gaussian-MLE": lambda f,
    xdata,
    ydata,
    p0,
    bounds,
    sigma,
    absolute_sigma: emely_curve_fit(
        f,
        xdata,
        ydata,
        p0=p0,
        bounds=bounds,
        sigma=sigma,
        absolute_sigma=absolute_sigma,
        noise="folded-gaussian",
    ),
}

# %%
# define model parameters
dx = 10e-9  # (m)
mu = 0  # (m)
sigma = 300e-9  # (m)
P = 5e-3  # (W)
p = (P, mu, sigma)

# define model variables
x_rng = (-3 * sigma, 3 * sigma)
n_x = round((x_rng[1] - x_rng[0]) / dx) + 1
x = x_rng[0] + dx * np.arange(n_x)

# set the random seed
np.random.seed(0)

# %%
# create N measurements
f_x = gaussian(x, *p)
N = 1_000

# define the noise parameters
sigma_noise = 1e3  # (W/m)
weight = np.random.random()

# parameter estimates
p_opt = {name: np.zeros((N, len(p))) for name in estimators}
p_cov = {name: np.zeros((N, len(p), len(p))) for name in estimators}

# track run times
run_times = {name: np.zeros(N) for name in estimators}

y_x = np.zeros((N, n_x))
for ii in range(N):
    # add noise to measurement
    y_x[ii, :] = foldnorm.rvs(c=f_x / sigma_noise, scale=sigma_noise, loc=0)

    # define initial guesses
    P_0 = np.sum(y_x[ii, :] * dx)
    a_0 = P_0
    mu_0 = np.sum(x * y_x[ii, :] * dx) / P_0  # (m)
    var_0 = np.sum((x - mu_0) ** 2 * y_x[ii, :] * dx) / P_0  # (m^2)
    sigma_0 = np.sqrt(var_0) if var_0 > 0 else 1e-10  # (m)
    p_0 = (a_0, mu_0, sigma_0)

    # define bounds
    bounds = (
        [1e-18, -np.inf, 1e-18],
        [np.inf, np.inf, np.inf],
    )

    for name in estimators:
        try:
            t_1 = time.perf_counter()

            p_opt[name][ii, :], p_cov[name][ii, :, :] = estimators[name](
                gaussian,
                x,
                y_x[ii, :],
                p0=p_0,
                bounds=bounds,
                sigma=sigma_noise * weight,
                absolute_sigma=False,
            )

            t_2 = time.perf_counter()
            run_times[name][ii] = t_2 - t_1
        except RuntimeError:
            p_opt[name][ii, :] = np.nan * np.ones(len(p))
            p_cov[name][ii, :, :] = np.nan * np.ones((len(p), len(p)))

            run_times[name][ii] = np.nan
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 39
#      36 try:
#      37     t_1 = time.perf_counter()
# ---> 39     p_opt[name][ii, :], p_cov[name][ii, :, :] = estimators[name](
#      40         gaussian,
#      41         x,
#      42         y_x[ii, :],
#      43         p0=p_0,
#      44         bounds=bounds,
#      45         sigma=sigma_noise * weight,
#      46         absolute_sigma=False,
#      47     )
#      49     t_2 = time.perf_counter()
#      50     run_times[name][ii] = t_2 - t_1
#
# Cell In[4], line 40, in <lambda>(f, xdata, ydata, p0, bounds, sigma, absolute_sigma)
#       1 # define estimators
#       2 estimators = {
#       3     "Least-Squares": lambda f,
#       4     xdata,
#       5     ydata,
#       6     p0,
#       7     bounds,
#       8     sigma,
#       9     absolute_sigma: scipy_curve_fit(
#      10         f,
#      11         xdata,
#      12         ydata,
#      13         p0=p0,
#      14         bounds=bounds,
#      15         sigma=sigma,
#      16         absolute_sigma=absolute_sigma,
#      17     ),
#      18     "Gaussian-MLE": lambda f,
#      19     xdata,
#      20     ydata,
#      21     p0,
#      22     bounds,
#      23     sigma,
#      24     absolute_sigma: emely_curve_fit(
#      25         f,
#      26         xdata,
#      27         ydata,
#      28         p0=p0,
#      29         bounds=bounds,
#      30         sigma=sigma,
#      31         absolute_sigma=absolute_sigma,
#      32         noise="gaussian",
#      33     ),
#      34     "Folded-Gaussian-MLE": lambda f,
#      35     xdata,
#      36     ydata,
#      37     p0,
#      38     bounds,
#      39     sigma,
# ---> 40     absolute_sigma: emely_curve_fit(
#      41         f,
#      42         xdata,
#      43         ydata,
#      44         p0=p0,
#      45         bounds=bounds,
#      46         sigma=sigma,
#      47         absolute_sigma=absolute_sigma,
#      48         noise="folded-gaussian",
#      49     ),
#      50 }
#
# File ~\OneDrive - ICFO\Postdoc\General\Code\emely\emely\wrapper.py:86, in curve_fit(f, xdata, ydata, p0, bounds, sigma, absolute_sigma, method, noise, **optimizer_kwargs)
#      82     raise ValueError(f'Invalid noise type "{noise}".')
#      84 estimator = MLE(model, **optimizer_kwargs)
# ---> 86 params, params_cov = estimator.fit(
#      87     x_data,
#      88     y_data,
#      89     params_init,
#      90     param_bounds,
#      91     sigma_y,
#      92     is_sigma_y_absolute,
#      93 )
#      95 popt = params
#      96 pcov = params_cov
#
# File ~\OneDrive - ICFO\Postdoc\General\Code\emely\emely\base.py:188, in BaseMLE.fit(self, x_data, y_data, params_init, param_bounds, sigma_y, is_sigma_y_absolute)
#     142 def fit(
#     143     self,
#     144     x_data,
#    (...)    149     is_sigma_y_absolute=False,
#     150 ):
#     151     """
#     152     Perform maximum likelihood estimation fit.
#     153
#    (...)    179         Estimated covariance matrix. Shape (num_params, num_params).
#     180     """
#     181     (
#     182         x_data,
#     183         y_data,
#     184         params_init,
#     185         param_bounds,
#     186         sigma_y,
#     187         is_sigma_y_absolute,
# --> 188     ) = self._check_fit_args(
#     189         x_data,
#     190         y_data,
#     191         params_init,
#     192         param_bounds,
#     193         sigma_y,
#     194         is_sigma_y_absolute,
#     195     )
#     197     self.params_init = params_init
#     198     self.param_bounds = param_bounds
#
# File ~\OneDrive - ICFO\Postdoc\General\Code\emely\emely\base.py:120, in BaseMLE._check_fit_args(self, x_data, y_data, params_init, param_bounds, sigma_y, is_sigma_y_absolute)
#     117     sigma_y = np.full_like(y_data, sigma_y)
#     119 if not self._is_semi_analytical and not is_sigma_y_absolute:
# --> 120     raise ValueError(
#     121         f"{self.__class__.__name__} requires is_sigma_y_absolute=True."
#     122     )
#     124 if param_bounds is not None:
#     125     param_bounds = list(zip(*param_bounds))
#
# ValueError: FoldedGaussianMLE requires is_sigma_y_absolute=True.

# %%
# print run time statistics
for name in estimators:
    print(
        f"{name}: {1e3 * np.nanmean(run_times[name]):.2f} +/- {1e3 * np.nanstd(run_times[name]):.2f} ms"
    )
# Out:
# Least-Squares: 2.58 +/- 1.18 ms
# Gaussian-MLE: 9.34 +/- 3.48 ms
# Folded-Gaussian-MLE: 19.88 +/- 6.24 ms

# %%
# show exemplary data and fit
fig, axs = plt.subplots(1, len(estimators), figsize=(4 * len(estimators), 3))

index = 0
for ii, name in enumerate(estimators):
    axs[ii].plot(
        1e9 * x, 1e-3 * gaussian(x, *p_opt[name][index, :]), color=red, label="Fit"
    )
    axs[ii].plot(1e9 * x, 1e-3 * gaussian(x, *p), color=blue, label="Ground truth")
    axs[ii].scatter(
        1e9 * x,
        1e-3 * y_x[index, :],
        s=20,
        edgecolor=black,
        facecolor=blue,
        label="Measurement",
    )
    axs[ii].legend()
    axs[ii].set_title(name)

    axs[ii].set_xlabel("x (nm)")
    axs[ii].set_ylabel("Intensity (W/mm)")

# %%
# parameter settings
colors = [red, yellow, blue]
parameter_names = ["Amplitude", "Center", "Width"]
parameter_units = ["(W/mm)", "(nm)", "(nm)"]
parameter_scaling = [1e3, 1e9, 1e9, 1e9]

# parameter estimates
parameter_estimates = {
    parameter_name: pd.DataFrame({}, columns=estimators.keys())
    for parameter_name in parameter_names
}
for ii, parameter_name in enumerate(parameter_names):
    for estimator_name in estimators:
        parameter_estimates[parameter_name][estimator_name] = p_opt[estimator_name][
            :, ii
        ]

# empirical and estimated standard deviations
p_emp_std = {}
p_est_std = {}
for ii, parameter_name in enumerate(parameter_names):
    p_emp_std[parameter_name] = {}
    p_est_std[parameter_name] = {}
    for estimator_name in estimators:
        p_emp_std[parameter_name][estimator_name] = np.sqrt(
            np.nanvar(p_opt[estimator_name][:, ii], axis=0)
        )
        p_est_std[parameter_name][estimator_name] = np.sqrt(
            np.nanmean(p_cov[estimator_name][:, ii, ii], axis=0)
        )

# %%
fig, axs = plt.subplots(1, len(p), figsize=(4 * len(p), 3))

for ii in range(len(p)):
    sns.violinplot(
        parameter_scaling[ii] * parameter_estimates[parameter_names[ii]],
        inner=None,
        palette=colors,
        linewidth=1,
        alpha=0.9,
        ax=axs[ii],
        zorder=10,
    )

    offset = 0.1
    location = np.arange(len(estimators))
    y = [
        parameter_scaling[ii]
        * parameter_estimates[parameter_names[ii]][estimator_name].mean()
        for estimator_name in estimators
    ]

    # estimated standard deviation
    yerr = [
        parameter_scaling[ii] * p_est_std[parameter_names[ii]][estimator_name]
        for estimator_name in estimators
    ]
    axs[ii].errorbar(
        location - offset,
        y,
        yerr=yerr,
        color=black,
        linewidth=1,
        fmt="s",
        markersize=6,
        capthick=1,
        capsize=4,
        label="Estimated error",
        zorder=15,
    )

    # empirical standard deviation
    yerr = [
        parameter_scaling[ii] * p_emp_std[parameter_names[ii]][estimator_name]
        for estimator_name in estimators
    ]
    axs[ii].errorbar(
        location + offset,
        y,
        yerr=yerr,
        color=black,
        linewidth=1,
        fmt="o",
        markersize=6,
        capthick=1,
        capsize=4,
        label="Empirical error",
        zorder=15,
    )

    # ground truth
    axs[ii].axhline(
        parameter_scaling[ii] * p[ii],
        color=black,
        linestyle="--",
        linewidth=1,
        label="Ground truth",
        zorder=5,
    )

    axs[ii].set_title("Estimated " + parameter_names[ii].lower(), loc="left")
    axs[ii].set_xlabel("Estimator")
    axs[ii].set_ylabel(parameter_names[ii] + " " + parameter_units[ii])
    legend = axs[ii].legend(frameon=True, framealpha=0.7)
    legend.get_frame().set_facecolor("white")
    legend.set_zorder(20)

fig.tight_layout()
